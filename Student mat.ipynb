# %% [markdown]
# # Student mat dataset

# %% [markdown]
# To filtering the warnings when we are doing the data analysis we are doing like this.

# %%
#Filter out the warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# After this,now we need to import the required libraries to perform the required operations.

# %%
#import the libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas import DataFrame,Series
import sys
import statsmodels.api as sm
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
#from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.tree import export_graphviz
#from sklearn.externals.six import StringIO
from IPython.display import Image
#import pydotplus
#import graphviz

# %% [markdown]
# After importing the required libraries, now we need to import the csv file of dataset from where you are stored in your system
# by selecting the required dataset csv file and by click on copy path option.

# %%
#getting csv file
df=pd.read_csv(r"C:\Users\mypc\Desktop\data science1\student\student-mat (1).csv")

# %% [markdown]
# printing the head of the dataset by using the following command

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# Now we need to find the shape of the dataset.

# %%
df.shape
# Out:
# (395, 33)

# %% [markdown]
# Now we need to get the information of the dataset.

# %%
df.info
# Out:
# <bound method DataFrame.info of     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# Now we need to get the columns of the dataset.

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# Here some information is not important, so we need to drop that information.

# %%
df=df.drop(['school', 'sex'],axis=1)

# %% [markdown]
# printing the head of the dataset by using the following command

# %%
df.head()
# Out:
#    age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  reason  \
# 0   18       U     GT3       A     4     4  at_home   teacher  course
# 1   17       U     GT3       T     1     1  at_home     other  course
# 2   15       U     LE3       T     1     1  at_home     other   other
# 3   15       U     GT3       T     4     2   health  services    home
# 4   16       U     GT3       T     3     3    other     other    home
#
#   guardian  ...  famrel  freetime  goout Dalc Walc health absences  G1  G2  G3
# 0   mother  ...       4         3      4    1    1      3        6   5   6   6
# 1   father  ...       5         3      3    1    1      3        4   5   5   6
# 2   mother  ...       4         3      2    2    3      3       10   7   8  10
# 3   mother  ...       3         2      2    1    1      5        2  15  14  15
# 4   father  ...       4         3      2    1    2      5        4   6  10  10
#
# [5 rows x 31 columns]

# %% [markdown]
# # Data Cleaning

# %%
df.isna().sum()
# Out:
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# Here the data will be cleaned as per our requirements

# %%
df.shape
# Out:
# (395, 31)

# %%
for col in df.columns:
    if df [col].isnull().sum()>3000:
       df.drop(col,axis=1,inplace=True)

# %%
df.shape
# Out:
# (395, 31)

# %%
df.isna().sum()
# Out:
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.drop(["address"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    age famsize Pstatus  Medu  Fedu     Mjob      Fjob  reason guardian  \
# 0   18     GT3       A     4     4  at_home   teacher  course   mother
# 1   17     GT3       T     1     1  at_home     other  course   father
# 2   15     LE3       T     1     1  at_home     other   other   mother
# 3   15     GT3       T     4     2   health  services    home   mother
# 4   16     GT3       T     3     3    other     other    home   father
#
#    traveltime  ...  famrel  freetime goout Dalc Walc health absences  G1  G2  \
# 0           2  ...       4         3     4    1    1      3        6   5   6
# 1           1  ...       5         3     3    1    1      3        4   5   5
# 2           1  ...       4         3     2    2    3      3       10   7   8
# 3           1  ...       3         2     2    1    1      5        2  15  14
# 4           1  ...       4         3     2    1    2      5        4   6  10
#
#    G3
# 0   6
# 1   6
# 2  10
# 3  15
# 4  10
#
# [5 rows x 30 columns]

# %%
df["guardian"].astype("category").value_counts()
# Out:
# mother    273
# father     90
# other      32
# Name: guardian, dtype: int64

# %%
for column in df:
    print(df[column].astype("category").value_counts())
    print("-----------------------------------------------")
# Out:
# 16    104
# 17     98
# 18     82
# 15     82
# 19     24
# 20      3
# 22      1
# 21      1
# Name: age, dtype: int64
# -----------------------------------------------
# GT3    281
# LE3    114
# Name: famsize, dtype: int64
# -----------------------------------------------
# T    354
# A     41
# Name: Pstatus, dtype: int64
# -----------------------------------------------
# 4    131
# 2    103
# 3     99
# 1     59
# 0      3
# Name: Medu, dtype: int64
# -----------------------------------------------
# 2    115
# 3    100
# 4     96
# 1     82
# 0      2
# Name: Fedu, dtype: int64
# -----------------------------------------------
# other       141
# services    103
# at_home      59
# teacher      58
# health       34
# Name: Mjob, dtype: int64
# -----------------------------------------------
# other       217
# services    111
# teacher      29
# at_home      20
# health       18
# Name: Fjob, dtype: int64
# -----------------------------------------------
# course        145
# ...

# %%
df["age"].astype("category").value_counts()
# Out:
# 16    104
# 17     98
# 18     82
# 15     82
# 19     24
# 20      3
# 22      1
# 21      1
# Name: age, dtype: int64

# %%
df["Medu"].astype("category").value_counts()
# Out:
# 4    131
# 2    103
# 3     99
# 1     59
# 0      3
# Name: Medu, dtype: int64

# %%
df["traveltime"].astype("category").value_counts()
# Out:
# 1    257
# 2    107
# 3     23
# 4      8
# Name: traveltime, dtype: int64

# %%
df["absences"].astype("category").value_counts()
# Out:
# 0     115
# 2      65
# 4      53
# 6      31
# 8      22
# 10     17
# 14     12
# 12     12
# 3       8
# 7       7
# 16      7
# 18      5
# 5       5
# 20      4
# 22      3
# 13      3
# 1       3
# 9       3
# 11      3
# 15      3
# 23      1
# 24      1
# 21      1
# 25      1
# 56      1
# 26      1
# 28      1
# 30      1
# 17      1
# 38      1
# 40      1
# 54      1
# 19      1
# 75      1
# Name: absences, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason',
#        'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup',
#        'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet',
#        'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health',
#        'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.drop("famsize",axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# age           0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.shape
# Out:
# (395, 29)

# %%
df.shape[0]
# Out:
# 395

# %%
df.shape[0]/395
# Out:
# 1.0

# %%
df.columns
# Out:
# Index(['age', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian',
#        'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3'],
#       dtype='object')

# %%
df.head()
# Out:
#    age Pstatus  Medu  Fedu     Mjob      Fjob  reason guardian  traveltime  \
# 0   18       A     4     4  at_home   teacher  course   mother           2
# 1   17       T     1     1  at_home     other  course   father           1
# 2   15       T     1     1  at_home     other   other   mother           1
# 3   15       T     4     2   health  services    home   mother           1
# 4   16       T     3     3    other     other    home   father           1
#
#    studytime  ...  famrel freetime goout Dalc Walc health absences  G1  G2  G3
# 0          2  ...       4        3     4    1    1      3        6   5   6   6
# 1          2  ...       5        3     3    1    1      3        4   5   5   6
# 2          2  ...       4        3     2    2    3      3       10   7   8  10
# 3          3  ...       3        2     2    1    1      5        2  15  14  15
# 4          2  ...       4        3     2    1    2      5        4   6  10  10
#
# [5 rows x 29 columns]

# %%
df.astype("object")
# Out:
#     age Pstatus Medu Fedu      Mjob      Fjob  reason guardian traveltime  \
# 0    18       A    4    4   at_home   teacher  course   mother          2
# 1    17       T    1    1   at_home     other  course   father          1
# 2    15       T    1    1   at_home     other   other   mother          1
# 3    15       T    4    2    health  services    home   mother          1
# 4    16       T    3    3     other     other    home   father          1
# ..   ..     ...  ...  ...       ...       ...     ...      ...        ...
# 390  20       A    2    2  services  services  course    other          1
# 391  17       T    3    1  services  services  course   mother          2
# 392  21       T    1    1     other     other  course    other          1
# 393  18       T    3    2  services     other  course   mother          3
# 394  19       T    1    1     other   at_home  course   father          1
#
#     studytime  ... famrel freetime goout Dalc Walc health absences  G1  G2  G3
# ...

# %%
df.dtypes
# Out:
# age            int64
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
df.select_dtypes(include=object)
# Out:
#     Pstatus      Mjob      Fjob  reason guardian schoolsup famsup paid  \
# 0         A   at_home   teacher  course   mother       yes     no   no
# 1         T   at_home     other  course   father        no    yes   no
# 2         T   at_home     other   other   mother       yes     no  yes
# 3         T    health  services    home   mother        no    yes  yes
# 4         T     other     other    home   father        no    yes  yes
# ..      ...       ...       ...     ...      ...       ...    ...  ...
# 390       A  services  services  course    other        no    yes  yes
# 391       T  services  services  course   mother        no     no   no
# 392       T     other     other  course    other        no     no   no
# 393       T  services     other  course   mother        no     no   no
# 394       T     other   at_home  course   father        no     no   no
#
#     activities nursery higher internet romantic
# 0           no     yes    yes       no       no
# ...

# %% [markdown]
# #  Exploratory data analysis

# %% [markdown]
# Now we need to get the tail of the dataset using following command.

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      age Pstatus  Medu  Fedu      Mjob      Fjob  reason guardian  traveltime  \
# 0     18       A     4     4   at_home   teacher  course   mother           2
# 1     17       T     1     1   at_home     other  course   father           1
# 2     15       T     1     1   at_home     other   other   mother           1
# 3     15       T     4     2    health  services    home   mother           1
# 4     16       T     3     3     other     other    home   father           1
# ..   ...     ...   ...   ...       ...       ...     ...      ...         ...
# 390   20       A     2     2  services  services  course    other           1
# 391   17       T     3     1  services  services  course   mother           2
# 392   21       T     1     1     other     other  course    other           1
# 393   18       T     3     2  services     other  course   mother           3
# 394   19       T     1     1     other   at_home  course   father           1
#
# ...

# %% [markdown]
# Plot couple of features to see if there is any relation between 'age', 'studytime', 'go out' and final score 'G3'

# %%
sns.factorplot('age','G3',data=df)
sns.factorplot('studytime','G3',data=df)
sns.factorplot('goout','G3',data=df)

# %% [markdown]
# As we can see in the figure above, the final score has a trend to go down as a student gets older.
# The cause of this maybe the distraction of college. Next, a funny fact is that not always the longer
# study time get the better results. This rule is only true in a limite of studytime, then
# if you continue to study you won't get the result that you want.
# Finally is the plot between time for going out and score.
# It shows that if you go out "enough", you will achieve the best score.

# %%
str_list = [] # empty list to contain columns with strings (words)

for colname, colvalue in df.iteritems():
    if type(colvalue[1]) == str:
         str_list.append(colname)
# Get to the numeric columns by inversion            
num_list = df.columns.difference(str_list) 
print(str_list)
print(num_list)
df = df[num_list]
# Out:
# ['Pstatus', 'Mjob', 'Fjob', 'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']
# Index(['Dalc', 'Fedu', 'G1', 'G2', 'G3', 'Medu', 'Walc', 'absences', 'age',
#        'failures', 'famrel', 'freetime', 'goout', 'health', 'studytime',
#        'traveltime'],
#       dtype='object')

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 10))
plt.title('Student Performance')
# Draw the heatmap using seaborn
sns.heatmap(df.astype(float).corr(),linewidths=0.25,vmax=1.0, square=True, cmap="YlGnBu", linecolor='black', annot=True)
# Out:
# <AxesSubplot:title={'center':'Student Performance'}>

# %% [markdown]
# From this figure we can see there are strong correlation between score in midterm and final score

# %%
np.sum(df.isnull())
# Out:
# Dalc          0
# Fedu          0
# G1            0
# G2            0
# G3            0
# Medu          0
# Walc          0
# absences      0
# age           0
# failures      0
# famrel        0
# freetime      0
# goout         0
# health        0
# studytime     0
# traveltime    0
# dtype: int64

# %%
y_train = df['G3']
x_train = df
x_train .drop(['G3'], axis=1,inplace=True)

# %%
number_of_samples = len(y_train)
print(len(y_train))
np.random.seed(0)
random_indices = np.random.permutation(number_of_samples)
num_training_samples = int(number_of_samples*0.75)
X_train = x_train.iloc[random_indices[:num_training_samples]]
Y_train= y_train.iloc[random_indices[:num_training_samples]]
X_test= x_train.iloc[random_indices[num_training_samples:]]
Y_test=y_train.iloc[random_indices[num_training_samples:]]
Y_Train=list(Y_train)
# Out:
# 395

# %%
from sklearn import neighbors

n_neighbors=5
knn=neighbors.KNeighborsRegressor(n_neighbors,weights='uniform')
knn.fit(X_train,Y_train)
y1_knn=knn.predict(X_train)
y1_knn=list(y1_knn)

train_error_knn = np.mean(abs(y1_knn-Y_train))
print(train_error_knn)

y_test=knn.predict(X_test)
y_Predict=list(y_test)

test_error_knn = np.mean(abs(y_Predict-Y_test))
print(test_error_knn)
# Out:
# 1.0317567567567558
# 1.084848484848485

# %%
from sklearn import svm
svm_reg=svm.SVR()
svm_reg.fit(X_train,Y_train)
y1_svm=svm_reg.predict(X_train)
y1_svm=list(y1_svm)
y2_svm=svm_reg.predict(X_test)
y2_svm=list(y2_svm)

train_error_svm = np.mean(abs(y1_svm-Y_train))
train_error_svm_std = np.std(abs(y1_svm-Y_train))
print(train_error_svm)

test_error_svm = np.mean(abs(y2_svm-Y_test))
print(test_error_svm)
# Out:
# 1.1885733956917002
# 1.1233774210594494

# %%
print(type(df))
df=DataFrame(df)
df.head()[:2]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Dalc  Fedu  G1  G2  Medu  Walc  absences  age  failures  famrel  freetime  \
# 0     1     4   5   6     4     1         6   18         0       4         3
# 1     1     1   5   5     1     1         4   17         0       5         3
#
#    goout  health  studytime  traveltime
# 0      4       3          2           2
# 1      3       3          2           1

# %%
train_error=[train_error_knn,train_error_svm]
test_error=[test_error_knn,test_error_svm]

col={'Train Error':train_error,'Test Error':test_error}
models=['Knn','SVM']
df=DataFrame(data=col,index=models)
df
# Out:
#      Train Error  Test Error
# Knn     1.031757    1.084848
# SVM     1.188573    1.123377

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>
